# %%
 import pandas as pd

# %%
a = pd.read_csv('rbc_ALRS.csv')
a
# Out:
#                                                 news_id ticker  \
# 0     mts-bank-private-voshel-v-spisok-luchshih-bank...   MTSS
# 1                              685023957a8aa93a0103b841   MTSS
# 2                              67cacfbd9a79472db2261dbd   MTSS
# 3                              67ee2b879a79474dd13bb3db   MTSS
# 4                              67cad2619a79473aaa0f2a5b   MTSS
# ...                                                 ...    ...
# 1494                           68b1b8ea9a7947a8b33f1e4a   MTSS
# 1495                           697c8d649a7947db0ab13811   MTSS
# 1496  afk-sistema-razvivaet-sotsialnoe-partnerstvo-s...   MTSS
# 1497                           6970486d9a794724b21e1a44   MTSS
# 1498  mts-bank-rasshiryaet-set-otdelenij-v-sankt-pet...   MTSS
#
#                                                     url  \
# 0     https://companies.rbc.ru/news/H0nXAx8uGq/mts-b...
# 1     https://spb.plus.rbc.ru/news/685023957a8aa93a0...
# ...

# %%
b = pd.read_csv('rbc_GAZP.csv')
b
# Out:
#                                                 news_id ticker  \
# 0                              683850c39a7947476769e180   GMKN
# 1     gruppa-fingo-otsenivaet-ryinok-gazoochistki-v-...   GMKN
# 2                              633bbf279a7947850ec82b61   GMKN
# 3                              5e3d38fa9a79473c61e9377e   GMKN
# 4                              6193fe2a9a794700cad2ab0b   GMKN
# ...                                                 ...    ...
# 1489                           68b80c159a7947c5081efffd   GMKN
# 1490                           5de8fff39a79470b36b2925c   GMKN
# 1491                           5dfdaec69a7947003498366e   GMKN
# 1492                           608a77fd2ae596154df27f20   GMKN
# 1493                           6447a7ed9a794769d1c0a96f   GMKN
#
#                                                     url  \
# 0     https://www.rbc.ru/quote/news/article/683850c3...
# 1     https://companies.rbc.ru/news/ndsWEhm0Az/grupp...
# ...

# %%
c = pd.read_csv('rbc_GMKN.csv')
c
# Out:
#                                                 news_id ticker  \
# 0                              699345359a79470a09fba8d4   SBER
# 1                              69a0410e9a79473c9532f6bd   SBER
# 2                              692820d39a79476c14f31858   SBER
# 3                              692da42b7a8aa90cc3762ef4   SBER
# 4                              697b527e9a79474e8d2bb6ee   SBER
# ...                                                 ...    ...
# 1494                           698cdc6e9a794703d90f272d   SBER
# 1495                           69903bef9a794726e4f40f7a   SBER
# 1496                           68d5283c9a79470e6325965a   SBER
# 1497                           691b1bc47a8aa9043ddc339e   SBER
# 1498  ne-prosto-pedagogi-kak-repetitoryi-podderzhiva...   SBER
#
#                                                     url  \
# 0     https://www.rbc.ru/radio/16/02/2026/699345359a...
# 1     https://www.rbc.ru/politics/26/02/2026/69a0410...
# ...

# %%
d = pd.read_csv('rbc_LKOH.csv')
d
# Out:
#                                                 news_id ticker  \
# 0        ekaterina-ledokol-bolshie-dannyie-na-vef-i-gvs   MGNT
# 1                              6725be089a794748e7ddd332   MGNT
# 2                              687de7719a7947bf4361d2f6   MGNT
# 3                              694d4eb69a79472f0e375128   MGNT
# 4                              6786082c9a79471a477cf524   MGNT
# ...                                                 ...    ...
# 1494  kak-v-25-raza-uvelichit-prodazhi-produktov-iz-...   MGNT
# 1495                           68f7bd589a794712a0de230f   MGNT
# 1496                           66fc1e899a79475de9b0146d   MGNT
# 1497                           694119b69a7947b58bc9763b   MGNT
# 1498  buduschee-otelnogo-biznesa-tsifrovizatsiya-ust...   MGNT
#
#                                                     url  \
# 0     https://companies.rbc.ru/news/CVzTYn684i/ekate...
# 1     https://www.rbc.ru/life/news/6725be089a794748e...
# ...

# %%
e = pd.read_csv('rbc_MGNT.csv')
e
# Out:
#                        news_id ticker  \
# 0     66964cad9a79476dfa199c2a   LKOH
# 1     64bfd34f9a7947435d449447   LKOH
# 2     678118569a79473c4b2b5aa8   LKOH
# 3     660bf47c9a79478dc6c5c58a   LKOH
# 4     697b133d9a794732abb15735   LKOH
# ...                        ...    ...
# 1495  5e2044559a7947497f0c4340   LKOH
# 1496  660bb3bf9a7947156799115a   LKOH
# 1497  67e2bd2c9a7947748ac7d57a   LKOH
# 1498  658bd4ce9a794706067a24d0   LKOH
# 1499  67d2b6809a794700676defeb   LKOH
#
#                                                     url  \
# 0     https://www.rbc.ru/business/16/07/2024/66964ca...
# 1      https://pro.rbc.ru/demo/64bfd34f9a7947435d449447
# 2     https://www.rbc.ru/industries/news/678118569a7...
# 3     https://www.rbc.ru/business/02/04/2024/660bf47...
# 4     https://kaliningrad.rbc.ru/kaliningrad/29/01/2...
# ...                                                 ...
# 1495  https://www.rbc.ru/quote/news/training/5e20445...
# ...

# %%
f = pd.read_csv('rbc_MTSS.csv')
f
# Out:
#                                                 news_id ticker  \
# 0                              68dfab699a79472bb5821a18   GAZP
# 1                              6937c3fa9a79477d138242ec   GAZP
# 2     mihail-konstantinov-za-godyi-rabotyi-nashi-kli...   GAZP
# 3                              690d99719a7947f42b9efe3b   GAZP
# 4                              68f9fcf67a8aa984d92b9495   GAZP
# ...                                                 ...    ...
# 1491                           692070609a79479880ddf2c5   GAZP
# 1492                           685acb669a7947ae3f19ae56   GAZP
# 1493                           6800dbee9a7947d90a150d3c   GAZP
# 1494                           68d67cda7a8aa9f11730ad55   GAZP
# 1495                           69a15cec9a7947127921433a   GAZP
#
#                                                     url  \
# 0     https://www.rbc.ru/business/03/10/2025/68dfab6...
# 1     https://kavkaz.rbc.ru/kavkaz/freenews/6937c3fa...
# ...

# %%
g = pd.read_csv('rbc_ROSN.csv')
g
# Out:
#                                                 news_id ticker  \
# 0     nsk-na-pmgf-ot-postavschika-k-strategicheskomu...   ROSN
# 1                              68fa04419a7947db12eb6b6e   ROSN
# 2                              620611b69a794741d09ea1e4   ROSN
# 3                              6409328b9a794764957a3141   ROSN
# 4                              63a1de909a7947b16ad0d560   ROSN
# ...                                                 ...    ...
# 1494                           663773279a79471fc0ca9696   ROSN
# 1495                           67c6e2b39a79479cef275ad7   ROSN
# 1496                           667e3e569a79476cde98bf1b   ROSN
# 1497                           645458989a7947cb23cba39e   ROSN
# 1498                           64c3c9499a7947cbb605fad8   ROSN
#
#                                                     url  \
# 0     https://companies.rbc.ru/news/xF5y8JOGkn/nsk-n...
# 1     https://www.rbc.ru/rbcfreenews/68fa04419a7947d...
# ...

# %%
h = pd.read_csv('rbc_SBER.csv')
h
# Out:
#                                                 news_id ticker  \
# 0                              67b5f8889a7947d8d324cb63   ALRS
# 1                              5c626b8f9a7947c5fa8162e3   ALRS
# 2                              5f685a8d9a794726b42289cc   ALRS
# 3                              5c220e8d9a794725de16bb99   ALRS
# 4                              6659cb029a79471c61bebd91   ALRS
# ...                                                 ...    ...
# 1492                           66f6baff9a794758454bd04b   ALRS
# 1493                           5ae098a92ae5961b67a1da82   ALRS
# 1494                           67a25ab19a79475a7e867d9d   ALRS
# 1495  v-tass-sostoyalos-ofitsialnoe-otkryitie-xiv-se...   ALRS
# 1496                           64e25c139a7947e80078cc95   ALRS
#
#                                                     url  \
# 0     https://www.rbc.ru/quote/news/article/67b5f888...
# 1     https://www.rbc.ru/quote/news/article/5c626b8f...
# ...

# %%
i = pd.read_csv('rbc_VTBR.csv')
i
# Out:
#                       news_id ticker  \
# 0    68af0ec39a79477bbf016655   VTBR
# 1    6920690f9a79470a0a50d8f1   VTBR
# 2    686b8e299a794761262879ec   VTBR
# 3    694948659a7947219b17bc92   VTBR
# 4    68fb4f479a79473dd34a00a3   VTBR
# ..                        ...    ...
# 694  68e8a7ed9a794743b4132305   VTBR
# 695  698c963b9a794797c852c796   VTBR
# 696  68abe8149a7947b49001e689   VTBR
# 697  689afb619a79472413df37e2   VTBR
# 698  6967aa4e7a8aa94ffa1a6466   VTBR
#
#                                                    url  \
# 0    https://www.rbc.ru/quote/news/article/68af0ec3...
# 1    https://realty.rbc.ru/news/6920690f9a79470a0a5...
# 2    https://realty.rbc.ru/news/686b8e299a794761262...
# 3    https://www.rbc.ru/quote/news/article/69494865...
# 4    https://rt.rbc.ru/tatarstan/freenews/68fb4f479...
# ..                                                 ...
# 694  https://www.rbc.ru/quote/news/article/68e8a7ed...
# 695  https://realty.rbc.ru/news/698c963b9a794797c85...
# ...

# %%
data = pd.concat([a, b, c, d, e, f, g,h, i], ignore_index=True)

# %%
data
# Out:
#                                                  news_id ticker  \
# 0      mts-bank-private-voshel-v-spisok-luchshih-bank...   MTSS
# 1                               685023957a8aa93a0103b841   MTSS
# 2                               67cacfbd9a79472db2261dbd   MTSS
# 3                               67ee2b879a79474dd13bb3db   MTSS
# 4                               67cad2619a79473aaa0f2a5b   MTSS
# ...                                                  ...    ...
# 12677                           68e8a7ed9a794743b4132305   VTBR
# 12678                           698c963b9a794797c852c796   VTBR
# 12679                           68abe8149a7947b49001e689   VTBR
# 12680                           689afb619a79472413df37e2   VTBR
# 12681                           6967aa4e7a8aa94ffa1a6466   VTBR
#
#                                                      url  \
# 0      https://companies.rbc.ru/news/H0nXAx8uGq/mts-b...
# 1      https://spb.plus.rbc.ru/news/685023957a8aa93a0...
# ...

# %%
data.isna().sum()
# Out:
# news_id                  0
# ticker                   0
# url                      0
# title                    0
# published_at          1744
# text                  2944
# category                 0
# sentiment_positive    2944
# sentiment_negative    2944
# sentiment_neutral     2944
# dtype: int64

# %%
data.to_csv('all_data.csv', index=False, encoding='utf-8-sig')
