# %%
#cкачиваем все 9 ноутбуков с GitHub
zapros = 'https://raw.githubusercontent.com/polina-orlova/hse_scraping_api_project_moex/refs/heads/feature/api/notebooks'
# !wget -q {zapros}/01_moex_api_SBER_final_2018_2025.ipynb
# !wget -q {zapros}/02_moex_api_GAZP_2018_2025.ipynb
# !wget -q {zapros}/03_moex_api_LKOH_2018_2025.ipynb
# !wget -q {zapros}/04_moex_api_ROSN_2018_2025.ipynb
# !wget -q {zapros}/05_moex_api_MTSS_2018_2025.ipynb
# !wget -q {zapros}/06_moex_api_GMKN_2018_2025.ipynb
# !wget -q {zapros}/07_moex_api_MGNT_2018_2025.ipynb
# !wget -q {zapros}/08_moex_api_ALRS_2018_2025.ipynb
# !wget -q {zapros}/09_moex_api_VTBR_2018_2025.ipynb

print('скачали с гитхаба все 9 колабов')
# Out:
# скачали с гитхаба все 9 колабов

# %%
# !mkdir -p moex_csvs #все csv тут будут

# %%
# %run 01_moex_api_SBER_final_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: Сбербанк России ПАО ао
# ISIN: RU0009029540
# Уровень листинга: 1
# Count of rows: 6
# Все дивиденты за 2018-01-01 - 2025-12-31: 6
# Count of rows: 1
# Последняя цена SBER: 320.16
# Изменение к пред. закрытию: -0.19
# Капитализация: 6911277271680
# Count of rows: 19
# SBER входит в IMOEX: True

# %%
df_SBERcandles.to_csv(f'moex_csvs/candles_SBER.csv', index=False)
df_SBER_infa_best.to_csv(f'moex_csvs/infa_SBER.csv', index=False)
df_SBER_diva_srok.to_csv(f'moex_csvs/diva_SBER.csv', index=False)
df_SBER_markdata_best.to_csv(f'moex_csvs/markdata_SBER.csv', index=False)
df_SBER_idishka.to_csv(f'moex_csvs/idishka_SBER.csv', index=False)

# %%
# %run 02_moex_api_GAZP_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: "Газпром" (ПАО) ао
# ISIN: RU0007661625
# Уровень листинга: 1
# Count of rows: 10
# Все дивиденты за 2018-01-01 - 2025-12-31: 6
# Count of rows: 1
# Последняя цена GAZP: 131.89
# Изменение к пред. закрытию: 0.88
# Капитализация: 3122299616381
# Count of rows: 19
# GAZP входит в IMOEX: True

# %%
df_GAZPcandles.to_csv(f'moex_csvs/candles_GAZP.csv', index=False)
df_GAZP_infa_best.to_csv(f'moex_csvs/infa_GAZP.csv', index=False)
df_GAZP_diva_srok.to_csv(f'moex_csvs/diva_GAZP.csv', index=False)
df_GAZP_markdata_best.to_csv(f'moex_csvs/markdata_GAZP.csv', index=False)
df_GAZP_idishka.to_csv(f'moex_csvs/idishka_GAZP.csv', index=False)

# %%
# %run 03_moex_api_LKOH_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: НК ЛУКОЙЛ (ПАО) - ао
# ISIN: RU0009024277
# Уровень листинга: 1
# Count of rows: 25
# Все дивиденты за 2018-01-01 - 2025-12-31: 14
# Count of rows: 1
# Последняя цена LKOH: 5807
# Изменение к пред. закрытию: 0.29
# Капитализация: 4023471479934
# Count of rows: 21
# LKOH входит в IMOEX: True

# %%
df_LKOHcandles.to_csv(f'moex_csvs/candles_LKOH.csv', index=False)
df_LKOH_infa_best.to_csv(f'moex_csvs/infa_LKOH.csv', index=False)
df_LKOH_diva_srok.to_csv(f'moex_csvs/diva_LKOH.csv', index=False)
df_LKOH_markdata_best.to_csv(f'moex_csvs/markdata_LKOH.csv', index=False)
df_LKOH_idishka.to_csv(f'moex_csvs/idishka_LKOH.csv', index=False)

# %%
# %run 04_moex_api_ROSN_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: ПАО НК Роснефть
# ISIN: RU000A0J2Q06
# Уровень листинга: 1
# Count of rows: 19
# Все дивиденты за 2018-01-01 - 2025-12-31: 14
# Count of rows: 1
# Последняя цена ROSN: 512.9
# Изменение к пред. закрытию: 0.18
# Капитализация: 5435805402339.3
# Count of rows: 20
# ROSN входит в IMOEX: True

# %%
df_ROSNcandles.to_csv(f'moex_csvs/candles_ROSN.csv', index=False)
df_ROSN_infa_best.to_csv(f'moex_csvs/infa_ROSN.csv', index=False)
df_ROSN_diva_srok.to_csv(f'moex_csvs/diva_ROSN.csv', index=False)
df_ROSN_markdata_best.to_csv(f'moex_csvs/markdata_ROSN.csv', index=False)
df_ROSN_idishka.to_csv(f'moex_csvs/idishka_ROSN.csv', index=False)

# %%
# %run 05_moex_api_MTSS_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 72
# Count of rows after 2072 rows: 0
# Total rows: 2072
# Count of rows: 27
# Полное название: Мобильные ТелеСистемы ПАО ао
# ISIN: RU0007775219
# Уровень листинга: 1
# Count of rows: 13
# Все дивиденты за 2018-01-01 - 2025-12-31: 13
# Count of rows: 1
# Последняя цена MTSS: 227.45
# Изменение к пред. закрытию: -0.11
# Капитализация: 454531889233.75
# Count of rows: 20
# MTSS входит в IMOEX: True

# %%
df_MTSScandles.to_csv(f'moex_csvs/candles_MTSS.csv', index=False)
df_MTSS_infa_best.to_csv(f'moex_csvs/infa_MTSS.csv', index=False)
df_MTSS_diva_srok.to_csv(f'moex_csvs/diva_MTSS.csv', index=False)
df_MTSS_markdata_best.to_csv(f'moex_csvs/markdata_MTSS.csv', index=False)
df_MTSS_idishka.to_csv(f'moex_csvs/idishka_MTSS.csv', index=False)

# %% [markdown]
# ---
# ## GMKN - Норникель

# %%
# %run 06_moex_api_GMKN_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 69
# Count of rows after 2069 rows: 0
# Total rows: 2069
# Count of rows: 27
# Полное название: ГМК "Нор.Никель" ПАО ао
# ISIN: RU0007288411
# Уровень листинга: 1
# Count of rows: 21
# Все дивиденты за 2018-01-01 - 2025-12-31: 11
# Count of rows: 1
# Последняя цена GMKN: 152.54
# Изменение к пред. закрытию: 0.01
# Капитализация: 2331778257838
# Count of rows: 23
# GMKN входит в IMOEX: True

# %%
df_GMKNcandles.to_csv(f'moex_csvs/candles_GMKN.csv', index=False)
df_GMKN_infa_best.to_csv(f'moex_csvs/infa_GMKN.csv', index=False)
df_GMKN_diva_srok.to_csv(f'moex_csvs/diva_GMKN.csv', index=False)
df_GMKN_markdata_best.to_csv(f'moex_csvs/markdata_GMKN.csv', index=False)
df_GMKN_idishka.to_csv(f'moex_csvs/idishka_GMKN.csv', index=False)

# %% [markdown]
# ---
# ## MGNT - Магнит

# %%
# %run 07_moex_api_MGNT_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: "Магнит" ПАО ао
# ISIN: RU000A0JKQU8
# Уровень листинга: 3
# Count of rows: 24
# Все дивиденты за 2018-01-01 - 2025-12-31: 11
# Count of rows: 1
# Последняя цена MGNT: 3207
# Изменение к пред. закрытию: -0.93
# Капитализация: 326829715485
# Count of rows: 18
# MGNT входит в IMOEX: True

# %%
df_MGNTcandles.to_csv(f'moex_csvs/candles_MGNT.csv', index=False)
df_MGNT_infa_best.to_csv(f'moex_csvs/infa_MGNT.csv', index=False)
df_MGNT_diva_srok.to_csv(f'moex_csvs/diva_MGNT.csv', index=False)
df_MGNT_markdata_best.to_csv(f'moex_csvs/markdata_MGNT.csv', index=False)
df_MGNT_idishka.to_csv(f'moex_csvs/idishka_MGNT.csv', index=False)

# %% [markdown]
# ---
# ## ALRS - Алроса

# %%
# %run 08_moex_api_ALRS_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 73
# Count of rows after 2073 rows: 0
# Total rows: 2073
# Count of rows: 27
# Полное название: АЛРОСА ПАО ао
# ISIN: RU0007252813
# Уровень листинга: 1
# Count of rows: 14
# Все дивиденты за 2018-01-01 - 2025-12-31: 10
# Count of rows: 1
# Последняя цена ALRS: 37.75
# Изменение к пред. закрытию: -1.77
# Капитализация: 278027452532.5
# Count of rows: 23
# ALRS входит в IMOEX: True

# %%
df_ALRScandles.to_csv(f'moex_csvs/candles_ALRS.csv', index=False)
df_ALRS_infa_best.to_csv(f'moex_csvs/infa_ALRS.csv', index=False)
df_ALRS_diva_srok.to_csv(f'moex_csvs/diva_ALRS.csv', index=False)
df_ALRS_markdata_best.to_csv(f'moex_csvs/markdata_ALRS.csv', index=False)
df_ALRS_idishka.to_csv(f'moex_csvs/idishka_ALRS.csv', index=False)

# %% [markdown]
# ---
# ## VTBR - ВТБ

# %%
# %run 09_moex_api_VTBR_2018_2025.ipynb
# Out:
# Авторизация успешна
# Cookie получен: True
# создали parametrs.txt с такими параметрами:
# enabled=true
# level=INFO
# filename=logs/logging_infa
# format=%(asctime)s - %(levelname)s - %(lineno)d - %(message)s
#
# Logging работает: уровень=INFO, файл=logs/logging_infa
# Count of rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 500 rows: 500
# Count of rows after 1000 rows: 500
# Count of rows after 1500 rows: 500
# Count of rows after 2000 rows: 69
# Count of rows after 2069 rows: 0
# Total rows: 2069
# Count of rows: 27
# Полное название: ао ПАО Банк ВТБ
# ISIN: RU000A0JP5V6
# Уровень листинга: 1
# Count of rows: 11
# Все дивиденты за 2018-01-01 - 2025-12-31: 6
# Count of rows: 1
# Последняя цена VTBR: 85.905
# Изменение к пред. закрытию: -0.07
# Капитализация: 568727032515.21
# Count of rows: 17
# VTBR входит в IMOEX: True

# %%
df_VTBRcandles.to_csv(f'moex_csvs/candles_VTBR.csv', index=False)
df_VTBR_infa_best.to_csv(f'moex_csvs/infa_VTBR.csv', index=False)
df_VTBR_diva_srok.to_csv(f'moex_csvs/diva_VTBR.csv', index=False)
df_VTBR_markdata_best.to_csv(f'moex_csvs/markdata_VTBR.csv', index=False)
df_VTBR_idishka.to_csv(f'moex_csvs/idishka_VTBR.csv', index=False)
